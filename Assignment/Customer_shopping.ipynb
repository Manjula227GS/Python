# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/Manju/Desktop/P.vvv/customer_shopping_data.csv/customer_shopping_data.csv")

# %%
data.shape
# Out:
# (99457, 10)

# %%
data.keys()
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
data.values
# Out:
# array([['I138884', 'C241288', 'Female', ..., 'Credit Card', '5/8/2022',
#         'Kanyon'],
#        ['I317333', 'C111565', 'Male', ..., 'Debit Card', '12/12/2021',
#         'Forum Istanbul'],
#        ['I127801', 'C266599', 'Male', ..., 'Cash', '9/11/2021',
#         'Metrocity'],
#        ...,
#        ['I824010', 'C103292', 'Male', ..., 'Debit Card', '28/03/2021',
#         'Metrocity'],
#        ['I702964', 'C800631', 'Male', ..., 'Cash', '16/03/2021',
#         'Istinye Park'],
#        ['I232867', 'C273973', 'Female', ..., 'Credit Card', '15/10/2022',
#         'Mall of Istanbul']], shape=(99457, 10), dtype=object)

# %%
pd.DataFrame(data)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data.shape
# Out:
# (99457, 10)

# %% [markdown]
# ## Dataset Columns

# %%
data.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %% [markdown]
# # Beginner-Level (Basic Pandas Operations)

# %% [markdown]
# ## 1.Load the dataset into a pandas DataFrame.

# %%
pd.DataFrame(data)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %% [markdown]
# ## 2.Display the first 5 rows.

# %%
data[0:6]
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
# 5    I227836     C657758  Female   28  Clothing         5  1500.40
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon
# 5    Credit Card   24/05/2022  Forum Istanbul

# %%
data.loc[:5,:]
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
# 5    I227836     C657758  Female   28  Clothing         5  1500.40
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon
# 5    Credit Card   24/05/2022  Forum Istanbul

# %%
data.iloc[:6,:]
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
# 5    I227836     C657758  Female   28  Clothing         5  1500.40
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon
# 5    Credit Card   24/05/2022  Forum Istanbul

# %% [markdown]
# ## 3.Show the data types of each column.

# %%
pd.DataFrame(data).dtypes
# Out:
# invoice_no         object
# customer_id        object
# gender             object
# age                 int64
# category           object
# quantity            int64
# price             float64
# payment_method     object
# invoice_date       object
# shopping_mall      object
# dtype: object

# %%
data.dtypes
# Out:
# invoice_no         object
# customer_id        object
# gender             object
# age                 int64
# category           object
# quantity            int64
# price             float64
# payment_method     object
# invoice_date       object
# shopping_mall      object
# dtype: object

# %% [markdown]
# ## 4.Find the number of unique values in the gender column.

# %%
data['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data['gender'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Female
# 1          Male
# 2          Male
# 3        Female
# 4        Female
#           ...
# 99452    Female
# 99453      Male
# 99454      Male
# 99455      Male
# 99456    Female
# Name: gender, Length: 99457, dtype: object>

# %% [markdown]
# ## 5.Display the maximum and minimum age of customers.

# %%
data['age'].min()
# Out:
# np.int64(18)

# %%
data['age'].max()
# Out:
# np.int64(69)

# %%
data['age'].agg(['min','max'])     ##agg means apply multiple aggregation operations across rows or columns of a dataframe
# Out:
# min    18
# max    69
# Name: age, dtype: int64

# %% [markdown]
# ## 6.Count null values in each column.

# %%
(data.isnull())
# Out:
#        invoice_no  customer_id  gender    age  category  quantity  price  \
# 0           False        False   False  False     False     False  False
# 1           False        False   False  False     False     False  False
# 2           False        False   False  False     False     False  False
# 3           False        False   False  False     False     False  False
# 4           False        False   False  False     False     False  False
# ...           ...          ...     ...    ...       ...       ...    ...
# 99452       False        False   False  False     False     False  False
# 99453       False        False   False  False     False     False  False
# 99454       False        False   False  False     False     False  False
# 99455       False        False   False  False     False     False  False
# 99456       False        False   False  False     False     False  False
#
#        payment_method  invoice_date  shopping_mall
# ...

# %%
(data.isnull()).sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
data.isna()
# Out:
#        invoice_no  customer_id  gender    age  category  quantity  price  \
# 0           False        False   False  False     False     False  False
# 1           False        False   False  False     False     False  False
# 2           False        False   False  False     False     False  False
# 3           False        False   False  False     False     False  False
# 4           False        False   False  False     False     False  False
# ...           ...          ...     ...    ...       ...       ...    ...
# 99452       False        False   False  False     False     False  False
# 99453       False        False   False  False     False     False  False
# 99454       False        False   False  False     False     False  False
# 99455       False        False   False  False     False     False  False
# 99456       False        False   False  False     False     False  False
#
#        payment_method  invoice_date  shopping_mall
# ...

# %% [markdown]
# ## 7.Filter transactions where payment_method is "cash".

# %%
data['payment_method'].unique()
# Out:
# array(['Credit Card', 'Debit Card', 'Cash'], dtype=object)

# %%
data[data['payment_method'] == 'Cash']
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 4        I337046     C189076  Female   53            Books         4    60.60
# 6        I121056     C151197  Female   49        Cosmetics         1    40.66
# 10       I306368     C240286  Female   36  Food & Beverage         2    10.46
# 13       I179802     C312861    Male   25         Clothing         2   600.16
# ...          ...         ...     ...  ...              ...       ...      ...
# 99449    I134399     C953724    Male   65         Clothing         1   300.08
# 99450    I170504     C226974  Female   28            Books         1    15.15
# 99451    I675411     C513603    Male   50             Toys         5   179.20
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
#
# ...

# %% [markdown]
# ## 8.Filter rows for transactions at "MetroCity Mall".

# %%
data['shopping_mall'].unique()
# Out:
# array(['Kanyon', 'Forum Istanbul', 'Metrocity', 'Metropol AVM',
#        'Istinye Park', 'Mall of Istanbul', 'Emaar Square Mall',
#        'Cevahir AVM', 'Viaport Outlet', 'Zorlu Center'], dtype=object)

# %%
data[data['shopping_mall']=='Metrocity']
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 8        I293455     C159642    Male   69         Clothing         3   900.24
# 10       I306368     C240286  Female   36  Food & Beverage         2    10.46
# 12       I640508     C225330  Female   67             Toys         4   143.36
# 16       I294687     C300786    Male   65            Books         2    30.30
# ...          ...         ...     ...  ...              ...       ...      ...
# 99405    I651573     C425890    Male   56            Shoes         3  1800.51
# 99408    I949512     C217355  Female   47         Clothing         2   600.16
# 99424    I549710     C541824  Female   34       Technology         3  3150.00
# 99433    I403904     C142643    Male   28             Toys         1    35.84
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
#
# ...

# %% [markdown]
# ## 9.Count the number of customers by gender.

# %%
data['gender'].count()
# Out:
# np.int64(99457)

# %%
data['gender'].value_counts()
# Out:
# gender
# Female    59482
# Male      39975
# Name: count, dtype: int64

# %% [markdown]
# ## 10.Rename the invoice_no column to invoice_number.

# %%
data=(data.rename(columns={'invoice_no': 'invoice_number'}))

# %%
data
# Out:
#       invoice_number customer_id  gender  age         category  quantity  \
# 0            I138884     C241288  Female   28         Clothing         5
# 1            I317333     C111565    Male   21            Shoes         3
# 2            I127801     C266599    Male   20         Clothing         1
# 3            I173702     C988172  Female   66            Shoes         5
# 4            I337046     C189076  Female   53            Books         4
# ...              ...         ...     ...  ...              ...       ...
# 99452        I219422     C441542  Female   45         Souvenir         5
# 99453        I325143     C569580    Male   27  Food & Beverage         2
# 99454        I824010     C103292    Male   63  Food & Beverage         2
# 99455        I702964     C800631    Male   56       Technology         4
# 99456        I232867     C273973  Female   36         Souvenir         3
#
#          price payment_method invoice_date     shopping_mall
# ...

# %% [markdown]
# # Intermediate-Level (Filtering, Grouping, Aggregation)

# %% [markdown]
# ## 11.Create a column total_price = quantity × price.

# %%
data
# Out:
#       invoice_number customer_id  gender  age         category  quantity  \
# 0            I138884     C241288  Female   28         Clothing         5
# 1            I317333     C111565    Male   21            Shoes         3
# 2            I127801     C266599    Male   20         Clothing         1
# 3            I173702     C988172  Female   66            Shoes         5
# 4            I337046     C189076  Female   53            Books         4
# ...              ...         ...     ...  ...              ...       ...
# 99452        I219422     C441542  Female   45         Souvenir         5
# 99453        I325143     C569580    Male   27  Food & Beverage         2
# 99454        I824010     C103292    Male   63  Food & Beverage         2
# 99455        I702964     C800631    Male   56       Technology         4
# 99456        I232867     C273973  Female   36         Souvenir         3
#
#          price payment_method invoice_date     shopping_mall
# ...

# %%
data['total_price']=(data['quantity'])*(data['price'])
data
# Out:
#       invoice_number customer_id  gender  age         category  quantity  \
# 0            I138884     C241288  Female   28         Clothing         5
# 1            I317333     C111565    Male   21            Shoes         3
# 2            I127801     C266599    Male   20         Clothing         1
# 3            I173702     C988172  Female   66            Shoes         5
# 4            I337046     C189076  Female   53            Books         4
# ...              ...         ...     ...  ...              ...       ...
# 99452        I219422     C441542  Female   45         Souvenir         5
# 99453        I325143     C569580    Male   27  Food & Beverage         2
# 99454        I824010     C103292    Male   63  Food & Beverage         2
# 99455        I702964     C800631    Male   56       Technology         4
# 99456        I232867     C273973  Female   36         Souvenir         3
#
#          price payment_method invoice_date     shopping_mall  total_price  \
# ...

# %% [markdown]
# ## 12.Find the average price by category.

# %%
data.groupby('category')['price'].mean()
# Out:
# category
# Books                45.568621
# Clothing            901.084021
# Cosmetics           122.448626
# Food & Beverage      15.671948
# Shoes              1807.388568
# Souvenir             34.894345
# Technology         3156.935548
# Toys                107.733185
# Name: price, dtype: float64

# %% [markdown]
# ## 13.Group by payment_method and sum quantity.

# %%
data['quantity'].sum()
# Out:
# np.int64(298712)

# %%
data.groupby('payment_method')['quantity'].sum().reset_index()
# Out:
#   payment_method  quantity
# 0           Cash    133370
# 1    Credit Card    105045
# 2     Debit Card     60297

# %% [markdown]
# ## 14. Calculate average age grouped by gender.

# %%
data
# Out:
#       invoice_number customer_id  gender  age         category  quantity  \
# 0            I138884     C241288  Female   28         Clothing         5
# 1            I317333     C111565    Male   21            Shoes         3
# 2            I127801     C266599    Male   20         Clothing         1
# 3            I173702     C988172  Female   66            Shoes         5
# 4            I337046     C189076  Female   53            Books         4
# ...              ...         ...     ...  ...              ...       ...
# 99452        I219422     C441542  Female   45         Souvenir         5
# 99453        I325143     C569580    Male   27  Food & Beverage         2
# 99454        I824010     C103292    Male   63  Food & Beverage         2
# 99455        I702964     C800631    Male   56       Technology         4
# 99456        I232867     C273973  Female   36         Souvenir         3
#
#          price payment_method invoice_date     shopping_mall  total_price  \
# ...

# %%
data.groupby('gender')['age'].mean()
# Out:
# gender
# Female    43.453515
# Male      43.387767
# Name: age, dtype: float64

# %%
data.groupby('gender')['age'].median()
# Out:
# gender
# Female    43.0
# Male      43.0
# Name: age, dtype: float64

# %% [markdown]
# ## 15.Create a bar chart of transaction counts per shopping_mall.

# %%
data.groupby('shopping_mall')['price'].count().plot(kind='bar',color=['red','green','blue','yellow','black','gray','pink','brown','orange'])
# Out:
# <Axes: xlabel='shopping_mall'>

# %% [markdown]
# ## 16.Count the number of invoices per customer_id.

# %%
data.groupby('invoice_number')['customer_id'].count().reset_index()
# Out:
#       invoice_number  customer_id
# 0            I100008            1
# 1            I100014            1
# 2            I100015            1
# 3            I100024            1
# 4            I100027            1
# ...              ...          ...
# 99452        I999956            1
# 99453        I999959            1
# 99454        I999972            1
# 99455        I999973            1
# 99456        I999994            1
#
# [99457 rows x 2 columns]

# %% [markdown]
# ## 17.List top 5 customers by total_price.

# %%
data.groupby('customer_id')['price'].sum().sort_values(ascending=False).head(5).reset_index()
# Out:
#   customer_id   price
# 0     C338164  5250.0
# 1     C998781  5250.0
# 2     C308063  5250.0
# 3     C275938  5250.0
# 4     C275961  5250.0

# %% [markdown]
# ## 18.Find top 3 most purchased category values.

# %%
data['category'].value_counts().head(3).reset_index()
# Out:
#           category  count
# 0         Clothing  34487
# 1        Cosmetics  15097
# 2  Food & Beverage  14776

# %% [markdown]
# ## 19.Convert invoice_date to datetime.

# %%
data["invoice_date"]=pd.to_datetime(data['invoice_date'], format='%d/%m/%Y')
data['invoice_date'].head()
# Out:
# 0   2022-08-05
# 1   2021-12-12
# 2   2021-11-09
# 3   2021-05-16
# 4   2021-10-24
# Name: invoice_date, dtype: datetime64[ns]

# %%
data
# Out:
#       invoice_number customer_id  gender  age         category  quantity  \
# 0            I138884     C241288  Female   28         Clothing         5
# 1            I317333     C111565    Male   21            Shoes         3
# 2            I127801     C266599    Male   20         Clothing         1
# 3            I173702     C988172  Female   66            Shoes         5
# 4            I337046     C189076  Female   53            Books         4
# ...              ...         ...     ...  ...              ...       ...
# 99452        I219422     C441542  Female   45         Souvenir         5
# 99453        I325143     C569580    Male   27  Food & Beverage         2
# 99454        I824010     C103292    Male   63  Food & Beverage         2
# 99455        I702964     C800631    Male   56       Technology         4
# 99456        I232867     C273973  Female   36         Souvenir         3
#
#          price payment_method invoice_date     shopping_mall  total_price  \
# ...

# %% [markdown]
# ## 20.Extract month from invoice_date and create a month column.

# %%
data['month']=data['invoice_date'].dt.month
data.head()
# Out:
#   invoice_number customer_id  gender  age  category  quantity    price  \
# 0        I138884     C241288  Female   28  Clothing         5  1500.40
# 1        I317333     C111565    Male   21     Shoes         3  1800.51
# 2        I127801     C266599    Male   20  Clothing         1   300.08
# 3        I173702     C988172  Female   66     Shoes         5  3000.85
# 4        I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall  total_price  month
# 0    Credit Card   2022-08-05          Kanyon      7502.00      8
# 1     Debit Card   2021-12-12  Forum Istanbul      5401.53     12
# 2           Cash   2021-11-09       Metrocity       300.08     11
# 3    Credit Card   2021-05-16    Metropol AVM     15004.25      5
# 4           Cash   2021-10-24          Kanyon       242.40     10

# %% [markdown]
# # Advanced-Level (Date Logic, Analysis, Visualization)

# %% [markdown]
# ## 21.Find the customer who spent the most.

# %%
data.groupby('customer_id')['total_price'].max().sort_values(ascending=False).head(1).reset_index()
# Out:
#   customer_id  total_price
# 0     C255975      26250.0

# %% [markdown]
# ## 22.Count transactions made on weekends.

# %%
data[data['invoice_date'].dt.day_of_week>=5].shape[0]
# Out:
# 28261

# %% [markdown]
# ## 23.Find which shopping mall had the highest sales in December.

# %%
data[data['invoice_date'].dt.month==12].groupby('shopping_mall')['total_price'].sum().sort_values(ascending=False).head(1).reset_index()
# Out:
#   shopping_mall  total_price
# 0        Kanyon   3965478.96

# %% [markdown]
# ## 24.Calculate the average transaction value.

# %%
data['total_price'].mean()
# Out:
# np.float64(2528.78926822647)

# %% [markdown]
# ## 25.Create a pivot table with average price by category and gender.
