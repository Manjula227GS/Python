# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/application_test.csv").shape
# Out:
# (48744, 121)

# %%
application_test = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/application_test.csv").shape
application_test
# Out:
# (48744, 121)

# %%
pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/POS_CASH_balance.csv").shape
# Out:
# (507019, 8)

# %%
POS_CASH_balance = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/POS_CASH_balance.csv").shape
POS_CASH_balance
# Out:
# (507019, 8)

# %%
pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/application_train.csv").shape
# Out:
# (307511, 122)

# %%
application_train = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/application_train.csv").shape
application_train
# Out:
# (307511, 122)

# %%
pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/bureau.csv").shape
# Out:
# (1716428, 17)

# %%
bureau = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/bureau.csv").shape
bureau
# Out:
# (1716428, 17)

# %%
pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/bureau_balance.csv").shape
# Out:
# (27299925, 3)

# %%
bureau_balance = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/bureau_balance.csv").shape
bureau_balance
# Out:
# (27299925, 3)

# %%
pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/HomeCredit_columns_description.csv", encoding='latin1').shape
# Out:
# (219, 5)

# %%
HomeCredit_columns_description = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/HomeCredit_columns_description.csv", encoding='latin1').shape
HomeCredit_columns_description
# Out:
# (219, 5)

# %%
bureau.keys()
# Out:
# Index(['SK_ID_CURR', 'SK_ID_BUREAU', 'CREDIT_ACTIVE', 'CREDIT_CURRENCY',
#        'DAYS_CREDIT', 'CREDIT_DAY_OVERDUE', 'DAYS_CREDIT_ENDDATE',
#        'DAYS_ENDDATE_FACT', 'AMT_CREDIT_MAX_OVERDUE', 'CNT_CREDIT_PROLONG',
#        'AMT_CREDIT_SUM', 'AMT_CREDIT_SUM_DEBT', 'AMT_CREDIT_SUM_LIMIT',
#        'AMT_CREDIT_SUM_OVERDUE', 'CREDIT_TYPE', 'DAYS_CREDIT_UPDATE',
#        'AMT_ANNUITY'],
#       dtype='object')

# %%
application_train = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/application_train.csv")
print(application_train.keys())
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %%
pd.merge(application_train, bureau, how = "left", on = "SK_ID_CURR")
# Out:
#          SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0            100002       1         Cash loans           M            N
# 1            100002       1         Cash loans           M            N
# 2            100002       1         Cash loans           M            N
# 3            100002       1         Cash loans           M            N
# 4            100002       1         Cash loans           M            N
# ...             ...     ...                ...         ...          ...
# 1509340      456255       0         Cash loans           F            N
# 1509341      456255       0         Cash loans           F            N
# 1509342      456255       0         Cash loans           F            N
# 1509343      456255       0         Cash loans           F            N
# 1509344      456255       0         Cash loans           F            N
#
#         FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# ...

# %%
bureau.keys()
# Out:
# Index(['SK_ID_CURR', 'SK_ID_BUREAU', 'CREDIT_ACTIVE', 'CREDIT_CURRENCY',
#        'DAYS_CREDIT', 'CREDIT_DAY_OVERDUE', 'DAYS_CREDIT_ENDDATE',
#        'DAYS_ENDDATE_FACT', 'AMT_CREDIT_MAX_OVERDUE', 'CNT_CREDIT_PROLONG',
#        'AMT_CREDIT_SUM', 'AMT_CREDIT_SUM_DEBT', 'AMT_CREDIT_SUM_LIMIT',
#        'AMT_CREDIT_SUM_OVERDUE', 'CREDIT_TYPE', 'DAYS_CREDIT_UPDATE',
#        'AMT_ANNUITY'],
#       dtype='object')

# %%
bureau_balance = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/bureau_balance.csv")
print(bureau_balance.keys())
# Out:
# Index(['SK_ID_BUREAU', 'MONTHS_BALANCE', 'STATUS'], dtype='object')

# %%
pd.merge( bureau,bureau_balance,on='SK_ID_BUREAU',how='left')
# Out:
#           SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0             215354       5714462        Closed      currency 1         -497
# 1             215354       5714463        Active      currency 1         -208
# 2             215354       5714464        Active      currency 1         -203
# 3             215354       5714465        Active      currency 1         -203
# 4             215354       5714466        Active      currency 1         -629
# ...              ...           ...           ...             ...          ...
# 25121810      259355       5057750        Active      currency 1          -44
# 25121811      100044       5057754        Closed      currency 1        -2648
# 25121812      100044       5057762        Closed      currency 1        -1809
# 25121813      246829       5057770        Closed      currency 1        -1878
# 25121814      246829       5057778        Closed      currency 1         -463
#
# ...

# %%
### right join

# %%
import pandas as pd

# %%
application_train = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/application_train.csv")
print(application_train.keys())
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %%
bureau = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/bureau.csv")
bureau.keys()
# Out:
# Index(['SK_ID_CURR', 'SK_ID_BUREAU', 'CREDIT_ACTIVE', 'CREDIT_CURRENCY',
#        'DAYS_CREDIT', 'CREDIT_DAY_OVERDUE', 'DAYS_CREDIT_ENDDATE',
#        'DAYS_ENDDATE_FACT', 'AMT_CREDIT_MAX_OVERDUE', 'CNT_CREDIT_PROLONG',
#        'AMT_CREDIT_SUM', 'AMT_CREDIT_SUM_DEBT', 'AMT_CREDIT_SUM_LIMIT',
#        'AMT_CREDIT_SUM_OVERDUE', 'CREDIT_TYPE', 'DAYS_CREDIT_UPDATE',
#        'AMT_ANNUITY'],
#       dtype='object')

# %%
pd.merge(application_train,bureau, on='SK_ID_CURR', how='right')
# Out:
#          SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0            215354     0.0         Cash loans           F            Y
# 1            215354     0.0         Cash loans           F            Y
# 2            215354     0.0         Cash loans           F            Y
# 3            215354     0.0         Cash loans           F            Y
# 4            215354     0.0         Cash loans           F            Y
# ...             ...     ...                ...         ...          ...
# 1716423      259355     1.0         Cash loans           M            Y
# 1716424      100044     0.0         Cash loans           M            N
# 1716425      100044     0.0         Cash loans           M            N
# 1716426      246829     0.0         Cash loans           F            N
# 1716427      246829     0.0         Cash loans           F            N
#
#         FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# ...

# %%
pd.merge(application_train,bureau, on='SK_ID_CURR', how='right').shape
# Out:
# (1716428, 138)

# %%
bureau = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/bureau.csv")
bureau.keys()
# Out:
# Index(['SK_ID_CURR', 'SK_ID_BUREAU', 'CREDIT_ACTIVE', 'CREDIT_CURRENCY',
#        'DAYS_CREDIT', 'CREDIT_DAY_OVERDUE', 'DAYS_CREDIT_ENDDATE',
#        'DAYS_ENDDATE_FACT', 'AMT_CREDIT_MAX_OVERDUE', 'CNT_CREDIT_PROLONG',
#        'AMT_CREDIT_SUM', 'AMT_CREDIT_SUM_DEBT', 'AMT_CREDIT_SUM_LIMIT',
#        'AMT_CREDIT_SUM_OVERDUE', 'CREDIT_TYPE', 'DAYS_CREDIT_UPDATE',
#        'AMT_ANNUITY'],
#       dtype='object')

# %%
POS_CASH_balance = pd.read_csv("C:/Users/Manju/Desktop/P.vvv/Assignment/POS_CASH_balance.csv")
POS_CASH_balance.keys()
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'MONTHS_BALANCE', 'CNT_INSTALMENT',
#        'CNT_INSTALMENT_FUTURE', 'NAME_CONTRACT_STATUS', 'SK_DPD',
#        'SK_DPD_DEF'],
#       dtype='object')
